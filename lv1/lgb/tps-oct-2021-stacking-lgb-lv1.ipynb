# %%
import numpy as np
import pandas as pd
import random
import os
import time
import pickle
from pathlib import Path

from os.path import join, isfile
from os import path, scandir, listdir

from sklearn.preprocessing import StandardScaler, QuantileTransformer
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score

import lightgbm as lgb
#import xgboost as xgb
#import catboost as ctb

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter('ignore')
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# # Parameters

# %%
target = 'target'

DEBUG = False

if DEBUG:
    N_ESTIMATORS = 1
    N_SPLITS = 2
    SEED = 2017
    CVSEED = 2017
    EARLY_STOPPING_ROUNDS = 1
    VERBOSE = 100
    #N_ITERS = 2
else:
    N_SPLITS = 5
    N_ESTIMATORS = 20000
    EARLY_STOPPING_ROUNDS = 300
    VERBOSE = 1000
    SEED = 2017
    CVSEED = 2017
    #N_ITERS = 10

# %%
def set_seed(seed=2017):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
set_seed(SEED)

# %% [markdown]
# # Datasets

# %%
INPUT = Path("../input/tabular-playground-series-oct-2021")

train = pd.DataFrame(pd.read_csv(INPUT / "train.csv")[target])
#test = pd.read_csv(INPUT / "test.csv")
test = pd.DataFrame()
submission = pd.read_csv(INPUT / "sample_submission.csv")

# %%
def list_all_files(location='../input/tps-oct-lv0', pattern=None, recursive=True):
    """
    This function returns a list of files at a given location (including subfolders)
    
    - location: path to the directory to be searched
    - pattern: part of the file name to be searched (ex. pattern='.csv' would return all the csv files)
    - recursive: boolean, if True the function calls itself for every subdirectory it finds
    """
    subdirectories= [f.path for f in scandir(location) if f.is_dir()]
    files = [join(location, f) for f in listdir(location) if isfile(join(location, f))]
    if recursive:
        for directory in subdirectories:
            files.extend(list_all_files(directory))
    if pattern:
        files = [f for f in files if pattern in f]
    return files

# %%
list_all_files(pattern='kosta')[1:6]  # printing only 5 files for simplicity
# Out:
# ['../input/tps-oct-lv0/2019_xgb_kosta_oof.npy',
#  '../input/tps-oct-lv0/2020xgb_kosta_pred.npy',
#  '../input/tps-oct-lv0/2020xgb_kosta_oof.npy',
#  '../input/tps-oct-lv0/2017xgb_kosta_pred.npy',
#  '../input/tps-oct-lv0/2021xgb_kosta_oof.npy']

# %%
names = ['bizen', 'henke', 'hamza', '28smiles','kashif', 'kosta', 'kaveh', 'dlaststark', 'pca', 'xgb2']

# %%
namesec = ['lonnie', 'hgb', 'xgb_d2s', 'ctb_d2s']

# %%
pred = list_all_files(pattern='oof')


for i in range(len(names)):
    cnt=1
    for file in pred:
        if names[i] in file.split('/')[3]:
            train[names[i]+str(cnt)] = np.load(file) 
            cnt += 1
            
pred = list_all_files(location='../input/tps-oct-lv0-sec', pattern='oof')

for i in range(len(namesec)):
    cnt=1
    for file in pred:
        if namesec[i] in file.split('/')[3]:
            train[namesec[i]+str(cnt)] = np.load(file) 
            cnt += 1
            
train.columns
# Out:
# Index(['target', 'bizen1', 'bizen2', 'bizen3', 'bizen4', 'bizen5', 'henke1',
#        'henke2', 'henke3', 'henke4', 'henke5', 'hamza1', 'hamza2', 'hamza3',
#        'hamza4', 'hamza5', '28smiles1', '28smiles2', '28smiles3', '28smiles4',
#        '28smiles5', 'kashif1', 'kashif2', 'kashif3', 'kashif4', 'kashif5',
#        'kosta1', 'kosta2', 'kosta3', 'kosta4', 'kosta5', 'kaveh1', 'kaveh2',
#        'kaveh3', 'kaveh4', 'kaveh5', 'dlaststark1', 'dlaststark2',
#        'dlaststark3', 'dlaststark4', 'dlaststark5', 'pca1', 'pca2', 'pca3',
#        'pca4', 'pca5', 'xgb21', 'xgb22', 'xgb23', 'xgb24', 'xgb25', 'lonnie1',
#        'lonnie2', 'lonnie3', 'lonnie4', 'lonnie5', 'hgb1', 'hgb2', 'hgb3',
#        'hgb4', 'hgb5', 'xgb_d2s1', 'xgb_d2s2', 'xgb_d2s3', 'xgb_d2s4',
#        'xgb_d2s5', 'ctb_d2s1', 'ctb_d2s2', 'ctb_d2s3', 'ctb_d2s4', 'ctb_d2s5'],
#       dtype='object')

# %%
pred = list_all_files(pattern='pred')


for i in range(len(names)):
    cnt=1
    for file in pred:
        if names[i] in file.split('/')[3]:
            test[names[i]+str(cnt)] = np.load(file) 
            cnt += 1
            
pred = list_all_files(location='../input/tps-oct-lv0-sec', pattern='pred')

for i in range(len(namesec)):
    cnt=1
    for file in pred:
        if namesec[i] in file.split('/')[3]:
            test[namesec[i]+str(cnt)] = np.load(file) 
            cnt += 1
    
test.columns
# Out:
# Index(['bizen1', 'bizen2', 'bizen3', 'bizen4', 'bizen5', 'henke1', 'henke2',
#        'henke3', 'henke4', 'henke5', 'hamza1', 'hamza2', 'hamza3', 'hamza4',
#        'hamza5', '28smiles1', '28smiles2', '28smiles3', '28smiles4',
#        '28smiles5', 'kashif1', 'kashif2', 'kashif3', 'kashif4', 'kashif5',
#        'kosta1', 'kosta2', 'kosta3', 'kosta4', 'kosta5', 'kaveh1', 'kaveh2',
#        'kaveh3', 'kaveh4', 'kaveh5', 'dlaststark1', 'dlaststark2',
#        'dlaststark3', 'dlaststark4', 'dlaststark5', 'pca1', 'pca2', 'pca3',
#        'pca4', 'pca5', 'xgb21', 'xgb22', 'xgb23', 'xgb24', 'xgb25', 'lonnie1',
#        'lonnie2', 'lonnie3', 'lonnie4', 'lonnie5', 'hgb1', 'hgb2', 'hgb3',
#        'hgb4', 'hgb5', 'xgb_d2s1', 'xgb_d2s2', 'xgb_d2s3', 'xgb_d2s4',
#        'xgb_d2s5', 'ctb_d2s1', 'ctb_d2s2', 'ctb_d2s3', 'ctb_d2s4', 'ctb_d2s5'],
#       dtype='object')

# %%
for i in range(5):

    train['lgb'+str(i+1)] = np.load("../input/tps-oct-lv0/"+str(i+2017)+"lgb_oof.npy")
    test['lgb'+str(i+1)] = np.load("../input/tps-oct-lv0/"+str(i+2017)+"lgb_pred.npy")
    
    train['xgb'+str(i+1)] = np.load("../input/tps-oct-lv0/agg"+str(i+1)+"_xgb_oof.npy")
    test['xgb'+str(i+1)] = np.load("../input/tps-oct-lv0/agg"+str(i+1)+"_xgb_pred.npy")

# %%
train
# Out:
#         target    bizen1    bizen2    bizen3    bizen4    bizen5    henke1  \
# 0            1  0.685970  0.662352  0.683341  0.680801  0.662460  0.678655
# 1            1  0.164244  0.175831  0.182369  0.179480  0.184402  0.173803
# 0       0.725906  0.724935  0.726242  ...  0.735924  0.749800  0.736604
# 1       0.239175  0.249142  0.245428  ...  0.227521  0.233324  0.228091
# 2       0.910373  0.912450  0.910781  ...  0.905077  0.900574  0.903743
# 3       0.831223  0.835070  0.830312  ...  0.850002  0.852097  0.845113
# 4       0.277562  0.278863  0.269478  ...  0.258881  0.264470  0.254145
# ...          ...       ...       ...  ...       ...       ...       ...
# 499995  0.975485  0.974509  0.975618  ...  0.965599  0.966326  0.964697
# 499996  0.841652  0.841801  0.841009  ...  0.831002  0.827310  0.826358
# 499997  0.283416  0.288363  0.284486  ...  0.283945  0.290662  0.290384
# 499998  0.509124  0.504425  0.493857  ...  0.513092  0.505349  0.506657
# 499999  0.425416  0.429303  0.424570  ...  0.421709  0.420890  0.423769
#
#             xgb2      lgb3      xgb3      lgb4      xgb4      lgb5      xgb5
# 0       0.748552  0.743572  0.751432  0.729459  0.749871  0.740535  0.741732
# 1       0.231134  0.233782  0.234014  0.229059  0.234173  0.234675  0.232551
# 2       0.903727  0.906030  0.902198  0.904603  0.901317  0.903600  0.900759
# 3       0.856662  0.852321  0.852952  0.844508  0.854423  0.852309  0.851234
# 4       0.270479  0.256417  0.261957  0.256586  0.257069  0.253683  0.258448
# ...          ...       ...       ...       ...       ...       ...       ...
# 499995  0.967489  0.965199  0.966779  0.965412  0.965603  0.965045  0.965611
# 499996  0.831930  0.832500  0.831930  0.829926  0.831986  0.832744  0.830885
# 499997  0.285845  0.287821  0.287705  0.289969  0.290894  0.291508  0.293653
# 499998  0.509809  0.506968  0.499887  0.503565  0.512421  0.501782  0.497552
# 499999  0.420000  0.418231  0.420724  0.423468  0.415888  0.421781  0.424960
#
# [500000 rows x 80 columns]

# %%
train[target]
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 999995    1
# 999996    0
# 999997    0
# 999998    1
# 999999    0
# Name: target, Length: 1000000, dtype: int64

# %% [markdown]
# # LGB

# %%
lgb_params = {
                'objective': 'binary',
                     'n_estimators':N_ESTIMATORS,
                     'importance_type': 'gain',
                     'metric':'auc',
                     'boosting_type': 'gbdt',
                     'n_jobs' : -1,    
    
  'learning_rate': 0.0030682029318363025,
 'subsample': 0.09400129853762118,
 'subsample_freq': 1,
 'colsample_bytree': 0.9257742227316306,
 'reg_lambda': 0.7403435553728978,
 'reg_alpha': 0.3694788316288643,
 'min_child_weight': 27.664207135159696,
 'min_child_samples': 189,
 'num_leaves': 77,
 'max_depth': 7
    
}

# %%
lgb_oof = np.zeros(train.shape[0])
lgb_pred = np.zeros(test.shape[0])
lgb_importances = pd.DataFrame()


kf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=CVSEED)
seed_list=range(SEED, SEED+20)

for fold, (trn_idx, val_idx) in enumerate(kf.split(X=train[features], y=train[target])):
    print(f"===== fold {fold} =====")


    X_train = train[features].iloc[trn_idx]
    y_train = train[target].iloc[trn_idx]
    X_valid = train[features].iloc[val_idx]
    y_valid = train[target].iloc[val_idx]
    X_test = test[features]

        

    start = time.time()
    for inseed in seed_list:
        lgb_params['random_state'] = inseed

        pre_model = lgb.LGBMClassifier(**lgb_params)
        pre_model.fit(
                X_train, 
                y_train,
                eval_set=[(X_valid, y_valid)],
                eval_metric='auc',
                early_stopping_rounds=EARLY_STOPPING_ROUNDS,
                verbose=VERBOSE,
            )
        

        lgb_params2 = lgb_params.copy()
        lgb_params2['reg_lambda'] *= 0.9
        lgb_params2['reg_alpha'] *= 0.9
        lgb_params2['learning_rate'] *= 0.1
        model = lgb.LGBMClassifier(**lgb_params2)
        model.fit(
                X_train, y_train,
                eval_set=[(X_valid, y_valid)],
                eval_metric='auc',
                early_stopping_rounds=EARLY_STOPPING_ROUNDS,
                verbose=VERBOSE,
                init_model=pre_model
        )    

        with open(f"lgb_model{fold}_seed{inseed}.pkl", 'wb') as f:
            pickle.dump(model, f)
            
        
        fi_tmp = pd.DataFrame()
        fi_tmp['feature'] = X_train.columns
        fi_tmp['importance'] = model.feature_importances_
        fi_tmp['fold'] = fold
        fi_tmp['seed'] = inseed
        lgb_importances = lgb_importances.append(fi_tmp)


        lgb_oof[val_idx] += model.predict_proba(X_valid)[:,-1] / len(seed_list)
        lgb_pred += model.predict_proba(X_test)[:,-1] / len(seed_list)


    elapsed = time.time() - start
    auc = roc_auc_score(y_valid, lgb_oof[val_idx])
    print(f"fold {fold} - lgb auc: {auc:.6f}, elapsed time: {elapsed:.2f}sec\n")            

lgb_pred /= N_SPLITS
print(f"oof lgb_auc = {roc_auc_score(train[target], lgb_oof)}")

np.save("lgb_oof.npy", lgb_oof)
np.save("lgb_pred.npy", lgb_pred)
# Out:
# ===== fold 0 =====
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [589]	valid_0's auc: 0.856725
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [594]	valid_0's auc: 0.856726
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [372]	valid_0's auc: 0.856699
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856702
# Early stopping, best iteration is:
# [1126]	valid_0's auc: 0.856702
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [285]	valid_0's auc: 0.856684
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856692
# Early stopping, best iteration is:
# [966]	valid_0's auc: 0.856692
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [240]	valid_0's auc: 0.856692
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [501]	valid_0's auc: 0.856698
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [376]	valid_0's auc: 0.856682
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [637]	valid_0's auc: 0.856683
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [441]	valid_0's auc: 0.856698
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [515]	valid_0's auc: 0.856699
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [233]	valid_0's auc: 0.856677
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856688
# [2000]	valid_0's auc: 0.856692
# Early stopping, best iteration is:
# [2399]	valid_0's auc: 0.856693
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [351]	valid_0's auc: 0.856691
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856693
# [2000]	valid_0's auc: 0.856696
# Early stopping, best iteration is:
# [1933]	valid_0's auc: 0.856696
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [572]	valid_0's auc: 0.85668
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [654]	valid_0's auc: 0.85668
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [488]	valid_0's auc: 0.856667
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856667
# Early stopping, best iteration is:
# [749]	valid_0's auc: 0.856668
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856703
# Early stopping, best iteration is:
# [1051]	valid_0's auc: 0.856705
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [1092]	valid_0's auc: 0.856705
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [168]	valid_0's auc: 0.856704
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [291]	valid_0's auc: 0.856706
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [381]	valid_0's auc: 0.856706
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856708
# Early stopping, best iteration is:
# [991]	valid_0's auc: 0.856709
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [352]	valid_0's auc: 0.856694
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [587]	valid_0's auc: 0.856696
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [321]	valid_0's auc: 0.856692
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856698
# Early stopping, best iteration is:
# [1118]	valid_0's auc: 0.856698
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [487]	valid_0's auc: 0.85667
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856672
# [2000]	valid_0's auc: 0.856675
# [3000]	valid_0's auc: 0.856677
# Early stopping, best iteration is:
# [2959]	valid_0's auc: 0.856677
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856698
# Early stopping, best iteration is:
# [983]	valid_0's auc: 0.8567
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.8567
# Early stopping, best iteration is:
# [1116]	valid_0's auc: 0.8567
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856665
# Early stopping, best iteration is:
# [870]	valid_0's auc: 0.856671
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856671
# Early stopping, best iteration is:
# [872]	valid_0's auc: 0.856671
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [541]	valid_0's auc: 0.856694
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856694
# Early stopping, best iteration is:
# [908]	valid_0's auc: 0.856695
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [257]	valid_0's auc: 0.856706
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [382]	valid_0's auc: 0.856709
# fold 0 - lgb auc: 0.856710, elapsed time: 4504.85sec
#
# ===== fold 1 =====
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [666]	valid_0's auc: 0.857954
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857954
# Early stopping, best iteration is:
# [1124]	valid_0's auc: 0.857955
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [448]	valid_0's auc: 0.857957
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857958
# [2000]	valid_0's auc: 0.857961
# Early stopping, best iteration is:
# [2537]	valid_0's auc: 0.857963
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857955
# Early stopping, best iteration is:
# [751]	valid_0's auc: 0.857958
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857958
# Early stopping, best iteration is:
# [770]	valid_0's auc: 0.857958
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857943
# Early stopping, best iteration is:
# [953]	valid_0's auc: 0.857946
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857945
# Early stopping, best iteration is:
# [1110]	valid_0's auc: 0.857946
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [569]	valid_0's auc: 0.857951
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857953
# [2000]	valid_0's auc: 0.857955
# Early stopping, best iteration is:
# [1757]	valid_0's auc: 0.857955
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [178]	valid_0's auc: 0.857962
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857971
# Early stopping, best iteration is:
# [1455]	valid_0's auc: 0.857975
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [365]	valid_0's auc: 0.857962
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857966
# Early stopping, best iteration is:
# [1352]	valid_0's auc: 0.857967
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [555]	valid_0's auc: 0.857943
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857945
# Early stopping, best iteration is:
# [792]	valid_0's auc: 0.857946
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [532]	valid_0's auc: 0.857966
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857967
# Early stopping, best iteration is:
# [713]	valid_0's auc: 0.857968
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [317]	valid_0's auc: 0.857963
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857969
# Early stopping, best iteration is:
# [1058]	valid_0's auc: 0.85797
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857956
# Early stopping, best iteration is:
# [837]	valid_0's auc: 0.857958
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857958
# Early stopping, best iteration is:
# [967]	valid_0's auc: 0.857958
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857954
# Early stopping, best iteration is:
# [706]	valid_0's auc: 0.857968
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857967
# Early stopping, best iteration is:
# [755]	valid_0's auc: 0.857968
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [176]	valid_0's auc: 0.857966
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857972
# [2000]	valid_0's auc: 0.857974
# Early stopping, best iteration is:
# [1797]	valid_0's auc: 0.857976
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [626]	valid_0's auc: 0.85796
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.85796
# Early stopping, best iteration is:
# [1073]	valid_0's auc: 0.857961
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [397]	valid_0's auc: 0.857952
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [692]	valid_0's auc: 0.857955
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [274]	valid_0's auc: 0.857965
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857966
# Early stopping, best iteration is:
# [761]	valid_0's auc: 0.857968
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [177]	valid_0's auc: 0.857967
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857971
# Early stopping, best iteration is:
# [717]	valid_0's auc: 0.857974
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [391]	valid_0's auc: 0.857941
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857942
# [2000]	valid_0's auc: 0.857946
# [3000]	valid_0's auc: 0.857949
# Early stopping, best iteration is:
# [3195]	valid_0's auc: 0.85795
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [245]	valid_0's auc: 0.857961
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857968
# [2000]	valid_0's auc: 0.857972
# Early stopping, best iteration is:
# [2134]	valid_0's auc: 0.857973
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [452]	valid_0's auc: 0.857957
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.857958
# Early stopping, best iteration is:
# [902]	valid_0's auc: 0.857959
# fold 1 - lgb auc: 0.857976, elapsed time: 5229.69sec
#
# ===== fold 2 =====
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [459]	valid_0's auc: 0.858526
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858527
# Early stopping, best iteration is:
# [871]	valid_0's auc: 0.858528
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [534]	valid_0's auc: 0.858549
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.85855
# [2000]	valid_0's auc: 0.85855
# Early stopping, best iteration is:
# [1746]	valid_0's auc: 0.858552
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [320]	valid_0's auc: 0.858535
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858538
# Early stopping, best iteration is:
# [877]	valid_0's auc: 0.858539
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [188]	valid_0's auc: 0.858535
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858543
# [2000]	valid_0's auc: 0.85855
# Early stopping, best iteration is:
# [1987]	valid_0's auc: 0.85855
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [437]	valid_0's auc: 0.858537
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858537
# Early stopping, best iteration is:
# [719]	valid_0's auc: 0.858538
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858543
# Early stopping, best iteration is:
# [961]	valid_0's auc: 0.858546
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858546
# Early stopping, best iteration is:
# [1027]	valid_0's auc: 0.858546
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [360]	valid_0's auc: 0.858523
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858526
# [2000]	valid_0's auc: 0.85853
# Early stopping, best iteration is:
# [2399]	valid_0's auc: 0.858532
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [535]	valid_0's auc: 0.858519
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858521
# Early stopping, best iteration is:
# [1151]	valid_0's auc: 0.858521
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [567]	valid_0's auc: 0.85853
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [641]	valid_0's auc: 0.858531
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.85855
# Early stopping, best iteration is:
# [1061]	valid_0's auc: 0.858554
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [1237]	valid_0's auc: 0.858554
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858524
# Early stopping, best iteration is:
# [725]	valid_0's auc: 0.858536
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858537
# Early stopping, best iteration is:
# [1420]	valid_0's auc: 0.858539
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [636]	valid_0's auc: 0.858553
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858554
# Early stopping, best iteration is:
# [1164]	valid_0's auc: 0.858555
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [548]	valid_0's auc: 0.858521
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858522
# [2000]	valid_0's auc: 0.858524
# Early stopping, best iteration is:
# [2215]	valid_0's auc: 0.858525
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858544
# Early stopping, best iteration is:
# [889]	valid_0's auc: 0.858547
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858547
# Early stopping, best iteration is:
# [899]	valid_0's auc: 0.858547
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [305]	valid_0's auc: 0.858523
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858528
# [2000]	valid_0's auc: 0.858533
# Early stopping, best iteration is:
# [1956]	valid_0's auc: 0.858533
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.85854
# Early stopping, best iteration is:
# [1073]	valid_0's auc: 0.858542
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [1337]	valid_0's auc: 0.858543
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858538
# Early stopping, best iteration is:
# [1078]	valid_0's auc: 0.858539
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [1130]	valid_0's auc: 0.85854
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [185]	valid_0's auc: 0.858522
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858528
# [2000]	valid_0's auc: 0.858532
# Early stopping, best iteration is:
# [2478]	valid_0's auc: 0.858535
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858518
# Early stopping, best iteration is:
# [997]	valid_0's auc: 0.858519
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858519
# Early stopping, best iteration is:
# [1062]	valid_0's auc: 0.858519
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.85852
# Early stopping, best iteration is:
# [745]	valid_0's auc: 0.858527
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.858527
# Early stopping, best iteration is:
# [968]	valid_0's auc: 0.858527
# fold 2 - lgb auc: 0.858552, elapsed time: 5508.56sec
#
# ===== fold 3 =====
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [429]	valid_0's auc: 0.856981
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856985
# Early stopping, best iteration is:
# [1598]	valid_0's auc: 0.856987
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [363]	valid_0's auc: 0.856983
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856984
# Early stopping, best iteration is:
# [728]	valid_0's auc: 0.856985
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [616]	valid_0's auc: 0.856964
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856966
# Early stopping, best iteration is:
# [995]	valid_0's auc: 0.856966
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [633]	valid_0's auc: 0.856985
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856986
# Early stopping, best iteration is:
# [1270]	valid_0's auc: 0.856987
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856962
# Early stopping, best iteration is:
# [903]	valid_0's auc: 0.856966
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856965
# Early stopping, best iteration is:
# [913]	valid_0's auc: 0.856966
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.85699
# Early stopping, best iteration is:
# [837]	valid_0's auc: 0.856992
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856992
# Early stopping, best iteration is:
# [897]	valid_0's auc: 0.856993
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [338]	valid_0's auc: 0.856987
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [607]	valid_0's auc: 0.856991
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [543]	valid_0's auc: 0.85697
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [595]	valid_0's auc: 0.85697
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [547]	valid_0's auc: 0.856994
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856995
# Early stopping, best iteration is:
# [1105]	valid_0's auc: 0.856996
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [371]	valid_0's auc: 0.85699
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856992
# Early stopping, best iteration is:
# [703]	valid_0's auc: 0.856994
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [671]	valid_0's auc: 0.856983
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856983
# Early stopping, best iteration is:
# [924]	valid_0's auc: 0.856983
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [271]	valid_0's auc: 0.856972
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856977
# Early stopping, best iteration is:
# [1190]	valid_0's auc: 0.856979
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856993
# Early stopping, best iteration is:
# [898]	valid_0's auc: 0.856996
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856997
# Early stopping, best iteration is:
# [1108]	valid_0's auc: 0.856997
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856975
# Early stopping, best iteration is:
# [704]	valid_0's auc: 0.856988
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856989
# Early stopping, best iteration is:
# [821]	valid_0's auc: 0.85699
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [87]	valid_0's auc: 0.856953
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.85698
# [2000]	valid_0's auc: 0.856986
# Early stopping, best iteration is:
# [2588]	valid_0's auc: 0.85699
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [567]	valid_0's auc: 0.856982
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856984
# Early stopping, best iteration is:
# [1118]	valid_0's auc: 0.856985
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856962
# Early stopping, best iteration is:
# [750]	valid_0's auc: 0.856973
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856972
# Early stopping, best iteration is:
# [1072]	valid_0's auc: 0.856973
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856982
# Early stopping, best iteration is:
# [949]	valid_0's auc: 0.856985
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856985
# Early stopping, best iteration is:
# [975]	valid_0's auc: 0.856986
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [98]	valid_0's auc: 0.856965
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856981
# Early stopping, best iteration is:
# [768]	valid_0's auc: 0.856982
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [253]	valid_0's auc: 0.856989
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856995
# Early stopping, best iteration is:
# [1232]	valid_0's auc: 0.856997
# fold 3 - lgb auc: 0.857000, elapsed time: 4708.68sec
#
# ===== fold 4 =====
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [111]	valid_0's auc: 0.856884
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [537]	valid_0's auc: 0.856892
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856869
# Early stopping, best iteration is:
# [1021]	valid_0's auc: 0.856869
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [1052]	valid_0's auc: 0.85687
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [487]	valid_0's auc: 0.856877
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [522]	valid_0's auc: 0.856878
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [642]	valid_0's auc: 0.856904
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [646]	valid_0's auc: 0.856904
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856863
# Early stopping, best iteration is:
# [828]	valid_0's auc: 0.856871
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856871
# Early stopping, best iteration is:
# [1291]	valid_0's auc: 0.856873
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [468]	valid_0's auc: 0.856889
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [690]	valid_0's auc: 0.85689
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [324]	valid_0's auc: 0.856857
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [325]	valid_0's auc: 0.856857
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856855
# Early stopping, best iteration is:
# [922]	valid_0's auc: 0.85686
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856859
# Early stopping, best iteration is:
# [1520]	valid_0's auc: 0.856862
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [370]	valid_0's auc: 0.856874
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856877
# Early stopping, best iteration is:
# [1154]	valid_0's auc: 0.856878
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [351]	valid_0's auc: 0.856872
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856876
# [2000]	valid_0's auc: 0.85688
# Early stopping, best iteration is:
# [1972]	valid_0's auc: 0.85688
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856855
# Early stopping, best iteration is:
# [1220]	valid_0's auc: 0.856858
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [1221]	valid_0's auc: 0.856858
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [182]	valid_0's auc: 0.85684
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856854
# Early stopping, best iteration is:
# [1644]	valid_0's auc: 0.856859
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [371]	valid_0's auc: 0.856838
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.85684
# [2000]	valid_0's auc: 0.856848
# [3000]	valid_0's auc: 0.856855
# Early stopping, best iteration is:
# [3310]	valid_0's auc: 0.856857
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [358]	valid_0's auc: 0.856873
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856875
# Early stopping, best iteration is:
# [1157]	valid_0's auc: 0.856877
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [255]	valid_0's auc: 0.85687
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [260]	valid_0's auc: 0.85687
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [510]	valid_0's auc: 0.85689
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856892
# Early stopping, best iteration is:
# [1229]	valid_0's auc: 0.856893
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [359]	valid_0's auc: 0.856862
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856867
# [2000]	valid_0's auc: 0.856869
# Early stopping, best iteration is:
# [1719]	valid_0's auc: 0.856869
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856866
# Early stopping, best iteration is:
# [1297]	valid_0's auc: 0.856868
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [1598]	valid_0's auc: 0.856868
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [421]	valid_0's auc: 0.85687
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.856872
# [2000]	valid_0's auc: 0.856877
# [3000]	valid_0's auc: 0.856882
# Early stopping, best iteration is:
# [2956]	valid_0's auc: 0.856882
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [485]	valid_0's auc: 0.856869
# Training until validation scores don't improve for 300 rounds
# [1000]	valid_0's auc: 0.85687
# Early stopping, best iteration is:
# [1194]	valid_0's auc: 0.856871
# fold 4 - lgb auc: 0.856889, elapsed time: 5274.22sec
#
# oof lgb_auc = 0.8571674009368074

# %% [markdown]
# # OOF predictions

# %%
plt.plot(train[target], train[target])
plt.scatter(train[target], lgb_oof)

# %% [markdown]
# # Features importances

# %%
order = list(lgb_importances.groupby('feature').mean().sort_values('importance', ascending=False).index)

fig = plt.figure(figsize=(16, 16), tight_layout=True)
sns.barplot(x="importance", y="feature", data=lgb_importances.groupby('feature').mean().reset_index(), order=order)
plt.title("LGB feature importances")
# Out:
# Text(0.5, 1.0, 'LGB feature importances')

# %% [markdown]
# # Submission

# %%
submission[target] = lgb_pred
submission.to_csv("submission.csv", index=False)

submission
# Out:
#              id    target
# 0       1000000  0.653992
# 1       1000001  0.316007
# 2       1000002  0.847811
# 3       1000003  0.752751
# 4       1000004  0.340326
# ...         ...       ...
# 499995  1499995  0.897179
# 499996  1499996  0.744376
# 499997  1499997  0.354714
# 499998  1499998  0.500755
# 499999  1499999  0.441218
#
# [500000 rows x 2 columns]

# %% [markdown]
# # Log
#
# /////// all raw /////////
# ver1
